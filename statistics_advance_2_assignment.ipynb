# %% [markdown]
# statistics advance 2 assignment
#
# 1)What is hypothesis testing in statistics
#  - Hypothesis testing is a form of statistical inference that uses data from a sample to draw conclusions about a population parameter or a population probability distribution. First, a tentative assumption is made about the parameter or distribution. This assumption is called the null hypothesis and is denoted by H0
#
# 2) What is the null hypothesis, and how does it differ from the alternative hypothesis?
#   - The null hypothesis and alternative hypothesis are two statements used in statistical testing to explore a research question. The null hypothesis (H0) proposes that there is no significant effect or relationship between variables being studied, while the alternative hypothesis (H1 or Ha) suggests that a significant effect or relationship does exist. The goal of hypothesis testing is to determine whether there is enough evidence to reject the null hypothesis in favor of the alternative hypothesis.
#
#
# 3)What is the significance level in hypothesis testing, and why is it important?
#   - In hypothesis testing, the significance level (alpha, denoted as α) is the probability of incorrectly rejecting the null hypothesis when it's actually true. It's a threshold used to determine statistical significance and is crucial because it sets the maximum acceptable risk of making a false positive conclusion, or Type I error.
#
#
# 4)What does a P-value represent in hypothesis testing?
#   - In hypothesis testing, a p-value represents the probability of observing data as extreme as, or more extreme than, the data actually observed, assuming the null hypothesis is true. Essentially, it quantifies how likely the observed results are due to random chance if there were no real effect.
#
#
# 5)How do you interpret the P-value in hypothesis testing?
#  - The P-value in hypothesis testing represents the probability of observing results as extreme as, or more extreme than, the observed results, assuming the null hypothesis is true. A small P-value (typically less than 0.05) suggests that the observed results are unlikely to have occurred by chance alone, leading to rejection of the null hypothesis. Conversely, a large P-value (greater than 0.05) indicates that the observed results are plausible under the null hypothesis, and the null hypothesis is not rejected.
#
#
#  6)What are Type 1 and Type 2 errors in hypothesis testing?
#    - In hypothesis testing, a Type I error (false positive) occurs when you reject a true null hypothesis, and a Type II error (false negative) occurs when you fail to reject a false null hypothesis.
#
#
#  7)What is the difference between a one-tailed and a two-tailed test in hypothesis testing?
#    - In hypothesis testing, a one-tailed test looks for a difference in one specific direction (either greater than or less than), while a two-tailed test looks for a difference in either direction (greater than or less than). This difference in direction affects the placement of the critical region (rejection region) and the interpretation of results.
#
#
# 8)What is the Z-test, and when is it used in hypothesis testing?
#  - A Z-test is a statistical method used in hypothesis testing to determine if there's a significant difference between a sample mean and a population mean, or between two sample means, when the population standard deviation is known, and the sample size is large. It's a method for testing hypotheses about population means when certain conditions are met.
#
#
#  9)How do you calculate the Z-score, and what does it represent in hypothesis testing?
#    - A Z-score indicates how many standard deviations a specific data point is from the mean of a dataset. It's calculated by subtracting the population mean from the data point and then dividing the result by the population standard deviation. In hypothesis testing, the Z-score helps determine the probability of observing a given data point or a more extreme value if the null hypothesis is true.
#
#
#  10)What is the T-distribution, and when should it be used instead of the normal distribution?
#    - The T-distribution is a probability distribution similar to the normal distribution, but with heavier tails, meaning it's more likely to produce extreme values. It's used when the population standard deviation is unknown, which is often the case, or when the sample size is small (typically less than 30). It's an alternative to the normal distribution in these situations because it's more accurate in estimating population parameters with limited data.
#
#
# 11)What is the difference between a Z-test and a T-test?
#   - The key difference between a Z-test and a T-test lies in the use of population standard deviation and sample size. Z-tests are used when the population standard deviation is known or when the sample size is large (generally n > 30), while T-tests are used when the population standard deviation is unknown and the sample size is small (generally n < 30).
#
#
# 12)What is the T-test, and how is it used in hypothesis testing?
#   - A t-test is a statistical hypothesis test used to determine if there's a significant difference between the means of two groups or populations. It's particularly useful when the population standard deviation is unknown, which is common when dealing with smaller sample sizes. In hypothesis testing, t-tests help determine if an observed difference between groups is likely due to chance or a real effect.
#
#
#
# 13)What is the relationship between Z-test and T-test in hypothesis testing?
#   - In hypothesis testing, Z-tests and T-tests are both used to compare population means to a sample mean, but they differ in their assumptions and applications. Z-tests are generally used with large sample sizes (n >= 30) and when the population standard deviation is known, while T-tests are used with smaller sample sizes (n < 30) or when the population standard deviation is unknown. Both tests assume a normal distribution of the data.
#
#
#
# 14)What is a confidence interval, and how is it used to interpret statistical results?
#   - A confidence interval is a range of values used to estimate an unknown population parameter based on sample data. It indicates the probability that the true population parameter falls within that range. Confidence intervals are typically used to quantify uncertainty in statistical analyses and are often constructed with a 95% or 99% confidence level.
#
#
# 15)What is the margin of error, and how does it affect the confidence interval?
#   - The margin of error represents the potential inaccuracy in an estimate, while the confidence interval provides a range within which the true population value is likely to fall. The margin of error directly affects the width of the confidence interval, and a larger margin of error leads to a wider interval.
#
#
# 16)How is Bayes' Theorem used in statistics, and what is its significance?
#   - Bayes' Theorem is a fundamental statistical tool used to calculate the conditional probability of an event based on prior knowledge and new evidence. It allows for the updating of probabilities as new information becomes available, making it valuable in areas like medical diagnosis and risk assessment.
#   - Significance:
# - Decision-Making:
# It helps in making more informed decisions under uncertainty by incorporating prior knowledge and new evidence.
# - Risk Assessment:
# It allows for the evaluation of risks and probabilities in various fields, including finance, healthcare, and machine learning.
# - Updating Beliefs:
# It provides a formal way to update one's beliefs about an event as new data becomes available.
# - Machine Learning:
# Bayes' Theorem is a key component of many machine learning algorithms, particularly in areas like classification and prediction.
#
#
# 17)What is the Chi-square distribution, and when is it used?
#  - The Chi-square distribution is a continuous probability distribution often used in hypothesis testing, specifically with categorical data. It's used to determine if observed data fits expected data (goodness-of-fit test) or if there's a relationship between two categorical variables (test of independence).
#
#
#
# 18)What is the Chi-square goodness of fit test, and how is it applied?
#   - The chi-square goodness-of-fit test is a statistical test used to determine how well a sample of data matches a specific theoretical distribution. It compares observed frequencies with expected frequencies under a hypothesized distribution.
# How it's applied:
# 1. Formulate a Hypothesis:
# The null hypothesis assumes the observed data follows the hypothesized distribution, while the alternative hypothesis suggests it does not.
# 2. Calculate Expected Frequencies:
# Based on the hypothesized distribution, calculate the expected number of observations for each category.
# 3. Calculate the Test Statistic:
# The chi-square test statistic is calculated using the formula: χ² = Σ (O - E)² / E, where O is the observed frequency and E is the expected frequency.
# 4. Determine Degrees of Freedom:
# Degrees of freedom (df) are calculated as df = k - 1, where k is the number of categories.
# 5. Compare to the Chi-Square Distribution:
# The calculated test statistic is compared to a chi-square distribution with the calculated degrees of freedom and a chosen significance level (alpha).
# 6. Draw a Conclusion:
# If the test statistic is greater than the critical value, the null hypothesis is rejected, meaning the observed data does not fit the hypothesized distribution well.
#
#
# 19)What is the F-distribution, and when is it used in hypothesis testing?
#   - The F-distribution is a probability distribution that's used in hypothesis testing, particularly when comparing variances between two or more populations. It's often used in conjunction with the F-test, which assesses whether the means of multiple groups are equal or if at least one group mean is significantly different from the others.
#
#
#
# 20)What is an ANOVA test, and what are its assumptions?
#   - An Analysis of Variance (ANOVA) test is a statistical method used to compare the means of three or more groups. It analyzes the variance within each group and between groups to determine if the differences between group means are significant. The assumptions of an ANOVA test include random sampling, independence of observations, normality of data within each group, and homogeneity of variance (equal variances) across groups.
#
#   - Assumptions of ANOVA
# - Random Sampling and Independence: The observations within each group must be sampled randomly and independently from each other.
# - Normality: The data within each group should be approximately normally distributed.
# - Homogeneity of Variance (Homoscedasticity): The variances within each group should be approximately equal.
# - Interval Data: The dependent variable should be measured on an interval scale.
#
#
# 21)What are the different types of ANOVA tests?
#   - The main types of ANOVA tests are one-way ANOVA and two-way ANOVA. One-way ANOVA compares means of a single independent variable with multiple levels, while two-way ANOVA examines the effects of two or more independent variables and their interactions.
#
#
#
# 22)What is the F-test, and how does it relate to hypothesis testing?
#   - The F-test is a statistical test that compares variances between two or more groups, primarily used in hypothesis testing to determine if there's a significant difference in means. It's related to hypothesis testing because it helps us decide whether to reject the null hypothesis of equal variances or equal means (depending on the context).

# %%
#practical part -1

#Write a Python program to generate a random variable and display its value
import random

# Generate a random integer between 1 and 10 (inclusive)
random_integer = random.randint(1, 10)

# Generate a random float between 0 and 1
random_float = random.random()

# Display the generated random values
print("Random Integer:", random_integer)
print("Random Float:", random_float)
# Out:
# Random Integer: 3
# Random Float: 0.7336675952376439

# %%
#Generate a discrete uniform distribution using Python and plot the probability mass function (PMF)
import numpy as np
import matplotlib.pyplot as plt

# Define the range of the discrete uniform distribution
low = 1
high = 10

# Generate a sample of the discrete uniform distribution
num_samples = 1000
samples = np.random.randint(low, high + 1, num_samples)

# Calculate the PMF
values, counts = np.unique(samples, return_counts=True)
pmf = counts / len(samples)

# Plot the PMF
plt.bar(values, pmf)
plt.xlabel("Value")
plt.ylabel("Probability")
plt.title("Probability Mass Function of a Discrete Uniform Distribution")
plt.xticks(np.arange(low, high + 1))
plt.show()

# %%
#Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution
import numpy as np
import scipy.stats as stats

def bernoulli_pdf(x, p):
    """
    Calculates the probability density function (PDF) of a Bernoulli distribution.

    Args:
        x: The outcome (0 or 1) of the Bernoulli trial.
        p: The probability of success (0 < p <= 1).

    Returns:
        The probability of observing the outcome x.
    """

    if x == 0:
        return (1 - p)
    elif x == 1:
        return p
    else:
        return 0  # Probability is 0 for outcomes other than 0 or 1

# %%
#Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram
from scipy.stats import binom
# Parameters: n = trials, p = probability of success
n = 10  # number of trials
p = 0.5  # probability of success (fair coin toss)
k = 5  # desired number of successes
# Calculate probability mass function (PMF)
pmf_value = binom.pmf(k, n, p)
print(f"Probability of getting exactly {k} successes in {n} trials: {pmf_value:.4f}")
# Out:
# Probability of getting exactly 5 successes in 10 trials: 0.2461

# %%
#Create a Poisson distribution and visualize it using Python
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Define the rate parameter (lambda)
lam = 5

# Generate x values for the plot
x = np.arange(0, 20)

# Calculate the Poisson probabilities
y = poisson.pmf(x, lam)

# Create the plot
plt.figure(figsize=(8, 6))
plt.plot(x, y, 'bo-', label=f'Poisson (λ={lam})')
plt.xlabel('Number of Events')
plt.ylabel('Probability')
plt.title('Poisson Distribution')
plt.xticks(x)
plt.legend()
plt.grid(True)
plt.show()

# %%
#Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution

# %%
#Generate a continuous uniform distribution using NumPy and visualize it
import numpy as np
import matplotlib.pyplot as plt

# Define the range and number of samples
low = 0
high = 10
num_samples = 1000

# Generate the random numbers from a uniform distribution
uniform_data = np.random.uniform(low, high, num_samples)

# Create the histogram
plt.hist(uniform_data, bins=30, density=True, alpha=0.6, color='g')

# Add labels and title
plt.title('Continuous Uniform Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %%
#Simulate data from a normal distribution and plot its histogram
import numpy as np
import matplotlib.pyplot as plt

# Generating some random data
# for an example
data = np.random.normal(170, 10, 250)

# Plotting the histogram.
plt.hist(data, bins=25, density=True, alpha=0.6, color='b')

plt.show()

# %%
#Write a Python function to calculate Z-scores from a dataset and plot them
import numpy as np
import matplotlib.pyplot as plt

def calculate_and_plot_z_scores(data):
    """
    Calculates z-scores for a dataset and plots them.

    Args:
        data (list or numpy.ndarray): A list or numpy array of numerical data.
    """
    if not isinstance(data, (list, np.ndarray)):
        raise TypeError("Input data must be a list or numpy array.")

    if not all(isinstance(x, (int, float)) for x in data):
         raise ValueError("All elements in the input data must be numerical.")

    data_np = np.array(data)
    mean = np.mean(data_np)
    std_dev = np.std(data_np)

    if std_dev == 0:
        raise ZeroDivisionError("Standard deviation is zero, cannot calculate z-scores.")

    z_scores = (data_np - mean) / std_dev

    plt.figure(figsize=(10, 6))
    plt.scatter(range(len(z_scores)), z_scores)
    plt.axhline(y=0, color='r', linestyle='--')
    plt.title('Z-Scores of the Data')
    plt.xlabel('Data Point Index')
    plt.ylabel('Z-Score')
    plt.grid(True)
    plt.show()

# Example usage:
data = [15, 18, 21, 24, 27, 30, 12, 9, 33, 36]
calculate_and_plot_z_scores(data)

# %%
#Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.

# %%
#Simulate multiple samples from a normal distribution and verify the Central Limit Theorem
import numpy as np
import matplotlib.pyplot as plt

# Define parameters
population_size = 10000
sample_size = 100
num_samples = 500

# Generate a population with a normal distribution
population = np.random.normal(0, 1, population_size)

# Simulate sampling and calculate means
sample_means = []
for _ in range(num_samples):
    sample = np.random.choice(population, sample_size, replace=False)
    sample_means.append(np.mean(sample))

# Plot the distribution of sample means
plt.hist(sample_means, bins=30, density=True, alpha=0.6, color='g')

# Overlay a normal distribution curve
mean_sample_means = np.mean(sample_means)
std_sample_means = np.std(sample_means)
x = np.linspace(mean_sample_means - 3*std_sample_means, mean_sample_means + 3*std_sample_means, 100)
plt.plot(x, 1/(std_sample_means * np.sqrt(2 * np.pi)) * np.exp( - (x - mean_sample_means)**2 / (2 * std_sample_means**2) ), color='r')

plt.title('Distribution of Sample Means')
plt.xlabel('Sample Mean')
plt.ylabel('Density')
plt.show()

# %%
#Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1)
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_standard_normal_distribution(x_start=-4, x_end=4, num_points=1000):
  """
  Calculates and plots the standard normal distribution.

  Args:
    x_start: The starting value for the x-axis range.
    x_end: The ending value for the x-axis range.
    num_points: The number of points to generate within the range.
  """
  x = np.linspace(x_start, x_end, num_points)
  y = norm.pdf(x, 0, 1) # Mean=0, Standard deviation=1

  plt.plot(x, y)
  plt.title('Standard Normal Distribution')
  plt.xlabel('x')
  plt.ylabel('Probability Density')
  plt.grid(True)
  plt.show()

if __name__ == '__main__':
  plot_standard_normal_distribution()

# %%
#Generate random variables and calculate their corresponding probabilities using the binomial distribution
import numpy as np
from scipy.stats import binom

# Define the parameters of the binomial distribution
n = 10  # Number of trials
p = 0.5  # Probability of success on each trial

# Generate random variables from the binomial distribution
num_samples = 1000
random_variables = np.random.binomial(n, p, num_samples)

# Calculate the probabilities for each possible outcome (0 to n successes)
possible_outcomes = np.arange(0, n + 1)
probabilities = binom.pmf(possible_outcomes, n, p)

# Print the random variables and their corresponding probabilities
print("Random Variables (first 20 samples):", random_variables[:20])
print("\nProbabilities for each outcome:")
for i, outcome in enumerate(possible_outcomes):
    print(f"P(X = {outcome}) = {probabilities[i]:.4f}")
# Out:
# Random Variables (first 20 samples): [2 4 4 6 4 6 8 4 8 6 3 6 6 3 7 7 6 4 3 8]
#
# Probabilities for each outcome:
# P(X = 0) = 0.0010
# P(X = 1) = 0.0098
# P(X = 2) = 0.0439
# P(X = 3) = 0.1172
# P(X = 4) = 0.2051
# P(X = 5) = 0.2461
# P(X = 6) = 0.2051
# P(X = 7) = 0.1172
# P(X = 8) = 0.0439
# P(X = 9) = 0.0098
# P(X = 10) = 0.0010

# %%
#Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution
import numpy as np
from scipy.stats import norm

def calculate_z_score(data_point, data):
    """
    Calculates the Z-score for a given data point within a dataset.

    Args:
        data_point (float or int): The data point to calculate the Z-score for.
        data (list or numpy.ndarray): The dataset.

    Returns:
        float: The calculated Z-score.
    """
    mean = np.mean(data)
    std_dev = np.std(data)
    z_score = (data_point - mean) / std_dev
    return z_score

def compare_to_standard_normal(z_score):
  """
  Compares a Z-score to the standard normal distribution.

  Args:
      z_score (float): The Z-score to compare.

  Returns:
      tuple: A tuple containing the probability of observing a value
             as extreme or more extreme than the Z-score (two-tailed test)
             and a string interpretation of the Z-score.
  """
  p_value = 2 * (1 - norm.cdf(abs(z_score))) # Two-tailed p-value
  interpretation = ""

  if abs(z_score) > 3:
    interpretation = "Very unusual (outlier)"
  elif abs(z_score) > 2:
    interpretation = "Unusual"
  elif abs(z_score) > 1:
    interpretation = "Moderately unusual"
  else:
    interpretation = "Typical"

  return p_value, interpretation

if __name__ == "__main__":
    data = [10, 12, 15, 18, 20, 22, 25, 28, 30, 35]
    data_point = 22

    z_score = calculate_z_score(data_point, data)
    p_value, interpretation = compare_to_standard_normal(z_score)

    print(f"Data point: {data_point}")
    print(f"Z-score: {z_score:.2f}")
    print(f"P-value: {p_value:.3f}")
    print(f"Interpretation: {interpretation}")
# Out:
# Data point: 22
# Z-score: 0.07
# P-value: 0.948
# Interpretation: Typical

# %%
#Implement hypothesis testing using Z-statistics for a sample dataset

# %%
#Create a confidence interval for a dataset using Python and interpret the result
import numpy as np
import scipy.stats as stats

d = [12, 15, 14, 10, 13, 17, 14, 15, 16, 14]
cl = 0.95 # confidence level

# confidence interval
import numpy as np
import statsmodels.api as sm

d = [12, 15, 14, 10, 13, 17, 14, 15, 16, 14]

# Create a model
X = sm.add_constant(np.array(d))
model = sm.OLS(d, X)
res = model.fit()

# Confidence interval
ci = res.conf_int(alpha=0.05)
print(ci)
# Out:
# [[-3.98583075e-14  7.88388442e-15]
#  [ 1.00000000e+00  1.00000000e+00]]

# %%
#Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean
import numpy as np
import scipy.stats as stats

# 1. Generate data from a normal distribution
# Set parameters for the normal distribution (mean, standard deviation, sample size)
true_mean = 10  # Population mean
true_std = 2   # Population standard deviation
sample_size = 100  # Number of samples

# Generate random samples from the normal distribution
data = np.random.normal(true_mean, true_std, sample_size)

# 2. Calculate the confidence interval
# Choose the desired confidence level (e.g., 95%)
confidence_level = 0.95
alpha = 1 - confidence_level

# Calculate the z-score corresponding to the confidence level
z_critical = stats.norm.ppf(1 - alpha / 2)

# Calculate the standard error of the mean
sample_mean = np.mean(data)
sample_std = np.std(data)  # Use sample standard deviation if population standard deviation is unknown
std_err = sample_std / np.sqrt(sample_size)

# Calculate the margin of error
margin_of_error = z_critical * std_err

# Calculate the confidence interval bounds
lower_bound = sample_mean - margin_of_error
upper_bound = sample_mean + margin_of_error

# Print the results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"Confidence Interval ({confidence_level * 100}%): ({lower_bound:.2f}, {upper_bound:.2f})")
# Out:
# Sample Mean: 9.62
# Confidence Interval (95.0%): (9.21, 10.04)

# %%
#Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Define the range of x values
x = np.linspace(-5, 5, 200)

# Define the mean and standard deviation
mu = 0
sigma = 1

# Calculate the PDF
pdf = norm.pdf(x, mu, sigma)

# Plot the PDF
plt.plot(x, pdf, label=f'μ={mu}, σ={sigma}')
plt.xlabel('x')
plt.ylabel('PDF(x)')
plt.title('Normal Distribution PDF')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution
import scipy.stats

# Example:  Calculate the CDF for x = 5 and lambda = 2
x = 5
lam = 2
cdf_value = scipy.stats.poisson.cdf(x, lam)

print(f"The CDF of a Poisson distribution with lambda = {lam} at x = {x} is: {cdf_value}")
# Out:
# The CDF of a Poisson distribution with lambda = 2 at x = 5 is: 0.9834363915193856

# %%
# Simulate a random variable using a continuous uniform distribution and calculate its expected value
import numpy as np

# Define the interval
a = 0
b = 1

# Generate 1000 samples
num_samples = 1000
samples = np.random.uniform(low=a, high=b, size=num_samples)

# Calculate the sample mean (estimated expected value)
sample_mean = np.mean(samples)
print(f"Sample Mean (Estimated Expected Value): {sample_mean}")

# Calculate the true expected value
expected_value = (a + b) / 2
print(f"True Expected Value: {expected_value}")
# Out:
# Sample Mean (Estimated Expected Value): 0.5067441508120699
# True Expected Value: 0.5

# %%
#Write a Python program to compare the standard deviations of two datasets and visualize the difference
from statistics import stdev

# different datasets
a = (1, 2, 5, 4, 8, 9, 12)
b = (-2, -4, -3, -1, -5, -6)
c = (-9, -1, 0, 2, 1, 3, 4, 19)
d = (1.23, 1.45, 2.1, 2.2, 1.9)

print(stdev(a))
print(stdev(b))
print(stdev(c))
print(stdev(d))
# Out:
# 3.9761191895520196
# 1.8708286933869707
# 7.8182478855559445
# 0.41967844833872525

# %%
#Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution
import numpy as np
from scipy import stats

# Generate a normally distributed dataset
data = np.random.normal(loc=0, scale=1, size=100)

# Calculate the range
range_ = np.max(data) - np.min(data)

# Calculate the interquartile range (IQR)
iqr = stats.iqr(data)

# Print the results
print("Range:", range_)
print("Interquartile Range (IQR):", iqr)
# Out:
# Range: 5.318472947227937
# Interquartile Range (IQR): 1.009222887879775

# %%
# Implement Z-score normalization on a dataset and visualize its transformation
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Generate a sample dataset
np.random.seed(42)
data = np.random.normal(loc=50, scale=20, size=100)

# Perform Z-score normalization
z_scores = stats.zscore(data)

# Visualize the original and normalized data
fig, axes = plt.subplots(2, 1, figsize=(8, 6))

axes[0].hist(data, bins=20, label='Original Data')
axes[0].set_title('Original Data Distribution')
axes[0].legend()

axes[1].hist(z_scores, bins=20, label='Z-score Normalized Data')
axes[1].set_title('Z-score Normalized Data Distribution')
axes[1].legend()

plt.tight_layout()
plt.show()

# Print descriptive statistics
print("Original Data:")
print("Mean:", np.mean(data))
print("Standard Deviation:", np.std(data))

print("\nZ-score Normalized Data:")
print("Mean:", np.mean(z_scores))
print("Standard Deviation:", np.std(z_scores))
# Out:
# Original Data:
# Mean: 47.92306965211812
# Standard Deviation: 18.072323532892593
#
# Z-score Normalized Data:
# Mean: -5.523359547510154e-17
# Standard Deviation: 0.9999999999999999

# %%
#Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution
import numpy as np
import scipy.stats as stats

def calculate_skewness_and_kurtosis(data):
  """
  Calculates the skewness and kurtosis of a dataset.

  Args:
    data: A NumPy array or a list of numerical values.

  Returns:
    A tuple containing the skewness and kurtosis values.
  """
  return stats.skew(data), stats.kurtosis(data)

# %%
#practical part -2

#Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and interpret the results
import numpy as np
from scipy import stats

def z_test_sample_mean(sample_data, pop_mean, pop_std, alpha=0.05, alternative='two-sided'):
    """
    Performs a Z-test to compare a sample mean to a population mean.

    Args:
        sample_data (list or numpy.ndarray): The sample data.
        pop_mean (float): The known population mean.
        pop_std (float): The known population standard deviation.
        alpha (float, optional): Significance level (default is 0.05).
        alternative (str, optional): Type of test ('two-sided', 'less', 'greater').
                                     Default is 'two-sided'.

    Returns:
        tuple: A tuple containing the z-statistic and the p-value.
    """
    n = len(sample_data)
    sample_mean = np.mean(sample_data)
    z_statistic = (sample_mean - pop_mean) / (pop_std / np.sqrt(n))

    if alternative == 'two-sided':
        p_value = 2 * stats.norm.cdf(-np.abs(z_statistic))
    elif alternative == 'less':
        p_value = stats.norm.cdf(z_statistic)
    elif alternative == 'greater':
        p_value = 1 - stats.norm.cdf(z_statistic)
    else:
        raise ValueError("alternative must be 'two-sided', 'less', or 'greater'")

    return z_statistic, p_value

# Example usage
sample = [78, 85, 92, 88, 81, 75, 95, 80, 89, 83]
population_mean = 85
population_std_dev = 8
significance_level = 0.05

z_stat, p_val = z_test_sample_mean(sample, population_mean, population_std_dev, alpha=significance_level)

print("Z-statistic:", z_stat)
print("P-value:", p_val)

if p_val < significance_level:
    print("Reject the null hypothesis. There is a significant difference between the sample mean and the population mean.")
else:
    print("Fail to reject the null hypothesis. There is no significant difference between the sample mean and the population mean.")
# Out:
# Z-statistic: -0.15811388300842122
# P-value: 0.8743670611628901
# Fail to reject the null hypothesis. There is no significant difference between the sample mean and the population mean.

# %%
#Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python
import numpy as np
from scipy import stats

# Simulate two random samples
np.random.seed(0)  # for reproducibility
sample1 = np.random.normal(loc=10, scale=2, size=50) # Sample from population with mean 10
sample2 = np.random.normal(loc=10.5, scale=2, size=50) # Sample from population with mean 10.5

# Perform an independent two-sample t-test
t_statistic, p_value = stats.ttest_ind(sample1, sample2)

# Print the results
print("T-statistic:", t_statistic)
print("P-value:", p_value)

# Interpret the p-value
alpha = 0.05 # significance level
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference between the two samples.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference between the two samples.")
# Out:
# T-statistic: -0.43601615616363415
# P-value: 0.6637839805374
# Fail to reject the null hypothesis: There is no significant difference between the two samples.

# %%
#Implement a one-sample Z-test using Python to compare the sample mean with the population mean
import numpy as np
from scipy.stats import norm

def one_sample_ztest(sample, popmean, popstd, alternative='two-sided', alpha=0.05):
    """
    Performs a one-sample Z-test.

    Args:
        sample (array-like): The sample data.
        popmean (float): The population mean.
        popstd (float): The population standard deviation.
        alternative (str, optional): The alternative hypothesis.
            Must be one of 'two-sided', 'less', or 'greater'.
            Defaults to 'two-sided'.
        alpha (float, optional): The significance level. Defaults to 0.05.

    Returns:
        tuple: A tuple containing the z-statistic and the p-value.
    """
    n = len(sample)
    sample_mean = np.mean(sample)
    z_stat = (sample_mean - popmean) / (popstd / np.sqrt(n))

    if alternative == 'two-sided':
        p_value = 2 * norm.cdf(-np.abs(z_stat))
    elif alternative == 'less':
        p_value = norm.cdf(z_stat)
    elif alternative == 'greater':
        p_value = 1 - norm.cdf(z_stat)
    else:
        raise ValueError("alternative must be 'two-sided', 'less', or 'greater'")

    return z_stat, p_value

# Example usage
sample_data = np.array([155, 160, 145, 150, 165, 140, 152, 158, 148, 162])
population_mean = 150
population_std = 10

z_statistic, p_value = one_sample_ztest(sample_data, population_mean, population_std)

print("Z-statistic:", z_statistic)
print("P-value:", p_value)

alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis")
else:
    print("Fail to reject the null hypothesis")
# Out:
# Z-statistic: 1.1067971810589328
# P-value: 0.2683816272927607
# Fail to reject the null hypothesis

# %%
#Perform a two-tailed Z-test using Python and visualize the decision region on a plot

# %%
#Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def visualize_errors(mu0, mu1, sigma, alpha):
    """
    Visualizes Type I and Type II errors in a one-sided hypothesis test.

    Args:
        mu0 (float):  Mean under the null hypothesis.
        mu1 (float):  Mean under the alternative hypothesis.
        sigma (float): Standard deviation.
        alpha (float): Significance level (Type I error rate).

    Returns:
        None. Displays a plot of the distributions and error regions.
    """

    # 1. Define the distributions
    x = np.linspace(mu0 - 4*sigma, mu0 + 4*sigma, 100)  # Range for x values
    null_dist = norm.pdf(x, mu0, sigma)  # Probability density under null
    alt_dist = norm.pdf(x, mu1, sigma)  # Probability density under alternative

    # 2. Calculate the critical value (rejection region)
    critical_value = norm.ppf(1-alpha, mu0, sigma)  # Inverse CDF for 1-alpha

    # 3. Calculate Type I error probability (false positive)
    type_i_error = norm.cdf(critical_value, mu0, sigma)  # Prob. of rejecting H0 when it's true

    # 4. Calculate Type II error probability (false negative)
    type_ii_error = norm.cdf(critical_value, mu1, sigma)  # Prob. of failing to reject H0 when it's false

    # 5. Plotting the distributions and error regions
    plt.figure(figsize=(10, 6))
    plt.plot(x, null_dist, label="Null Hypothesis (H0)", color="blue")
    plt.plot(x, alt_dist, label="Alternative Hypothesis (H1)", color="orange")
    plt.axvline(x=critical_value, color="red", linestyle="--", label=f"Critical Value (α={alpha})")

    # Fill in the error regions
    plt.fill_between(x[x < critical_value], null_dist[x < critical_value], color="red", alpha=0.3, label="Type I Error (False Positive)")
    plt.fill_between(x[x > critical_value], alt_dist[x > critical_value], color="green", alpha=0.3, label="Type II Error (False Negative)")

    plt.title("Visualizing Type I and Type II Errors")
    plt.xlabel("Sample Mean")
    plt.ylabel("Probability Density")
    plt.legend()
    plt.grid(True)
    plt.show()

# Example usage:
if __name__ == "__main__":
    mu0 = 50  # Mean under null hypothesis
    mu1 = 55  # Mean under alternative hypothesis
    sigma = 5  # Standard deviation
    alpha = 0.05  # Significance level

    visualize_errors(mu0, mu1, sigma, alpha)

# %%
#Write a Python program to perform an independent T-test and interpret the results
import numpy as np
from scipy import stats

# Sample data for two independent groups
group1 = np.array([25, 30, 28, 35, 22, 29, 31, 27, 33, 26])
group2 = np.array([20, 23, 25, 28, 21, 24, 26, 22, 27, 23])

# Perform independent T-test
t_statistic, p_value = stats.ttest_ind(group1, group2)

# Print the results
print("T-statistic:", t_statistic)
print("P-value:", p_value)

# Interpret the results
alpha = 0.05  # Significance level

if p_value < alpha:
    print("Reject the null hypothesis")
    print("There is a statistically significant difference between the means of the two groups.")
else:
    print("Fail to reject the null hypothesis")
    print("There is no statistically significant difference between the means of the two groups.")

# Further analysis
print("\nDescriptive statistics:")
print("Group 1 mean:", np.mean(group1))
print("Group 1 standard deviation:", np.std(group1))
print("Group 2 mean:", np.mean(group2))
print("Group 2 standard deviation:", np.std(group2))
# Out:
# T-statistic: 3.1905678965200157
# P-value: 0.005066436515175729
# Reject the null hypothesis
# There is a statistically significant difference between the means of the two groups.
#
# Descriptive statistics:
# Group 1 mean: 28.6
# Group 1 standard deviation: 3.6660605559646724
# Group 2 mean: 23.9
# Group 2 standard deviation: 2.467792535850613

# %%
#Perform a paired sample T-test using Python and visualize the comparison results

# %%
#Simulate data and perform both Z-test and T-test, then compare the results using Python
import numpy as np
from scipy import stats

# Simulate two datasets
np.random.seed(0)  # for reproducibility
sample_size = 50
group1 = np.random.normal(100, 15, sample_size)  # mean 100, std 15
group2 = np.random.normal(105, 15, sample_size)  # mean 105, std 15

# Z-test (assuming known population standard deviation)
population_std = 15
z_stat, z_p_value = stats.ztest(group1, group2, value=0, alternative='two-sided')

# T-test (assuming unknown population standard deviation)
t_stat, t_p_value = stats.ttest_ind(group1, group2, equal_var=True)

print("Z-test results:")
print(f"Z-statistic: {z_stat:.2f}")
print(f"P-value: {z_p_value:.3f}")

print("\nT-test results:")
print(f"T-statistic: {t_stat:.2f}")
print(f"P-value: {t_p_value:.3f}")

# Compare results
alpha = 0.05
print("\nComparison:")
if z_p_value < alpha:
    print("Z-test: Reject null hypothesis (significant difference)")
else:
    print("Z-test: Fail to reject null hypothesis (no significant difference)")

if t_p_value < alpha:
    print("T-test: Reject null hypothesis (significant difference)")
else:
    print("T-test: Fail to reject null hypothesis (no significant difference)")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-3772ab6874dd> in <cell line: 0>()
#      11 # Z-test (assuming known population standard deviation)
#      12 population_std = 15
# ---> 13 z_stat, z_p_value = stats.ztest(group1, group2, value=0, alternative='two-sided')
#      14
#      15 # T-test (assuming unknown population standard deviation)
#
# AttributeError: module 'scipy.stats' has no attribute 'ztest'

# %%
#Write a Python function to calculate the confidence interval for a sample mean and explain its significance
import numpy as np
import scipy.stats as stats

d = [12, 15, 14, 10, 13, 17, 14, 15, 16, 14]
cl = 0.95 # confidence level

# confidence interval
ci = stats.t.interval(confidence_level, df=len(d)-1, loc=np.mean(d), scale=np.std(d, ddof=1) / np.sqrt(len(d)))
print(ci)
# Out:
# (np.float64(12.56928618802332), np.float64(15.43071381197668))

# %%
#Write a Python program to calculate the margin of error for a given confidence level using sample data

# %%
#Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process
def bayes_theorem(prior_a, likelihood_ba, probability_b):
    """
    Calculates the posterior probability using Bayes' Theorem.

    Args:
        prior_a (float): Prior probability of hypothesis A.
        likelihood_ba (float): Likelihood of evidence B given hypothesis A.
        probability_b (float): Probability of evidence B.

    Returns:
        float: Posterior probability of hypothesis A given evidence B.
    """
    posterior_ab = (likelihood_ba * prior_a) / probability_b
    return posterior_ab

# %%
# Perform a Chi-square test for independence between two categorical variables in PythonE
    import pandas as pd
    from scipy.stats import chi2_contingency

    # Sample data
    data = {'Gender': ['Male', 'Female', 'Male', 'Female', 'Male', 'Female','Male', 'Female', 'Male', 'Female'],
            'Preference': ['A', 'B', 'A', 'A', 'B', 'B', 'A', 'B', 'B', 'A']}
    df = pd.DataFrame(data)

    # Create contingency table
    contingency_table = pd.crosstab(df['Gender'], df['Preference'])
    print("Contingency Table:")
    print(contingency_table)

    # Chi-square test
    chi2, p, dof, expected = chi2_contingency(contingency_table)

    print("\nChi-square Test Results:")
    print(f"Chi-square statistic: {chi2}")
    print(f"P-value: {p}")
    print(f"Degrees of freedom: {dof}")
    print("Expected frequencies:")
    print(expected)

    # Interpretation
    alpha = 0.05
    if p < alpha:
        print("\nReject the null hypothesis: There is a significant association between Gender and Preference.")
    else:
        print("\nFail to reject the null hypothesis: There is no significant association between Gender and Preference.")
# Out:
#   File "<ipython-input-34-672e62e80706>", line 2
#     import pandas as pd
#     ^
# IndentationError: unexpected indent

# %%
#Write a Python program to calculate the expected frequencies for a Chi-square test based on observed data

# %%
#Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution.
import numpy as np
from scipy.stats import chisquare

# Observed data
observed_values = np.array([25, 30, 20, 25])

# Expected data
expected_values = np.array([20, 35, 25, 20])

# Perform the Chi-squared test
chi2_statistic, p_value = chisquare(f_obs=observed_values, f_exp=expected_values)

print(f"Chi-squared Statistic: {chi2_statistic}")
print(f"P-value: {p_value}")

# Interpretation
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis: The observed data does not fit the expected distribution.")
else:
    print("Fail to reject the null hypothesis: The observed data fits the expected distribution.")
# Out:
# Chi-squared Statistic: 4.214285714285714
# P-value: 0.239235500667051
# Fail to reject the null hypothesis: The observed data fits the expected distribution.
